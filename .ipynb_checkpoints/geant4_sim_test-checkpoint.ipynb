# %%
import matplotlib.pyplot as plt
import astropy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/__init__.py in <module>
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/multiarray.py in <module>
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/overrides.py in <module>
#       5
# ----> 6 from numpy.core._multiarray_umath import (
#       7     add_docstring, implement_array_function, _get_implementing_args)
#
# ...
